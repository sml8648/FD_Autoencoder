# %%
import pandas as pd
import numpy as np

from classify import classify

# %%
clf = classify('220715')
df = clf.make_df()

# %%
# 임계치를 0으로 설정하여 0이상의 loss값이 나온 거래건에 대해서 자세히 조사
clf.draw_graph(df, threshold=0)

# %%
shap_df = clf.fetch_top_k(threshold=1)
# Out:
# LightGBM binary classifier with TreeExplainer shap values output has changed to a list of ndarray

# %%
# 해당 mse 값이 높게나온것에 대해 영향을 준 상위 10개의 값에 대한 분석
shap_df[['F1_value','F2_value','F3_value','F4_value','F5_value','F6_value','F7_value','F8_value','F9_value','F10_value']]
# Out:
#       F1_value  F2_value  F3_value  F4_value  F5_value  F6_value  F7_value  \
# 0    15.129698  8.486967  1.608701  0.933001  0.705685  0.418870  0.261776
# 1    17.090600  5.659369  1.766736  1.222747  0.987315  0.541962  0.311767
# 2    14.518396  8.906141  2.982008  1.012431  0.373991  0.318913  0.214579
# 3    14.756504  8.160319  2.404566  1.165453  0.854233  0.379373  0.339500
# 4    16.905201  5.841105  1.772535  1.247263  0.985721  0.547120  0.324511
# ..         ...       ...       ...       ...       ...       ...       ...
# 115  12.735593  4.295483  2.753464  1.252519  1.134816  0.878773  0.871022
# 116  12.731030  4.311308  2.753464  1.251886  1.134751  0.889646  0.868201
# 117  20.894553  3.619939  1.647423  0.725716  0.486188  0.357284  0.248287
# 118  20.851315  3.573874  1.669153  0.725856  0.565323  0.396342  0.249617
# 119   8.704187  5.455580  2.692489  2.453364  1.249324  1.146707  0.868785
#
#      F8_value  F9_value  F10_value
# 0    0.115373  0.091049   0.085471
# 1    0.196613  0.181520   0.160900
# 2    0.120760  0.085146   0.074104
# 3    0.142881  0.131879   0.098169
# 4    0.203204  0.175840   0.160722
# ..        ...       ...        ...
# 115  0.761338  0.748595   0.633773
# 116  0.753935  0.745508   0.633971
# 117  0.168626  0.152770   0.126889
# 118  0.168626  0.152875   0.126967
# 119  0.838495  0.820882   0.715285
#
# [120 rows x 10 columns]

# %%
# 여기 뭔 내용을 넣을까

# 우선 모델을 통과 시켜서 나온 그림을 보여주자
# 그다음에 shap을 보여주고
#
